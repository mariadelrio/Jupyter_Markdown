# %% [markdown]
# # Spring is coming!

# %% [markdown]
# ## Hopefully

# %% [markdown]
# ### I ja posats que surti el sol

# %%
# This is a comment before some code
print("Hello world!")
print("This is Maria pretending to do something productive with her life") # this is an in-line comment
# Out:
# Hello world!
# This is Maria pretending to do something productive with her life

# %%
my_number = 179
my_string = str(my_number)
print(my_number)
print(my_string)
# Out:
# 179
# 179

# %%
string_one = "I love "
string_two = "running"
string_three = string_one + string_two
print(string_three)
# Out:
# I love running

# %% [markdown]
# **hola**
#
# __hola__
#
# # hola (gran)
# ## hola (una mica més petit)
# ### hola (encara més petit)
# #### hola (petit)
#
# *hola*
#
# _hola_

# %% [markdown]
# ## Llista de la compra
# * patates
# * mandarines
# * pasta
#     * macarrons
#     * spaghetti
# * pollastre
# * peix

# %% [markdown]
# # Just another heading - for the sake of it and to introduce a fall picture

# %% [markdown]
# ![jupyter.jpg](attachment:jupyter.jpg)

# %% [markdown]
# ### Some easy operations

# %%
x = 1
y =  2

print (x+y)
print (x-y) 
print (x*y)
print (x/y)
# Out:
# 3
# -1
# 2
# 0.5
